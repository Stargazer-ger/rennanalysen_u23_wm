# %% [markdown]
# # Analyse der U23-WM Race-Data

# %%
# Imports
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt#
import pandas as pd

# %% [markdown]
# ## BW8+

# %%
# CSV Heat 1 aufrufen

heat1 = pd.read_csv('race_pdf/2023_u23_wm/bw8+/csv_output/bw8+_heat1.csv')

# CSV Heat 2 aufrufen

heat2 = pd.read_csv('race_pdf/2023_u23_wm/bw8+/csv_output/bw8+_heat2.csv')

# CSV Rep aufrufen

rep = pd.read_csv('race_pdf/2023_u23_wm/bw8+/csv_output/bw8+_rep1.csv')

# CSV Final aufrufen

final = pd.read_csv('race_pdf/2023_u23_wm/bw8+/csv_output/bw8+_final.csv')

# %%
# Heat 1

# Kopien erstellen und Renndaten zu float konvertieren

heat1_copy = heat1.copy()

race_data = heat1.iloc[3:43, 1:9].astype(float)

# Einteilen der Spalte pro Boot
dist = heat1_copy.iloc[3:43, 0]

heat1_gbr = race_data.iloc[:, 0:2]

heat1_rou = race_data.iloc[:, 2:4]

heat1_ned = race_data.iloc[:, 4:6]

heat1_can = race_data.iloc[:, 6:8]

print(dist.dtypes)
print(heat1_gbr.dtypes)
print(heat1_rou.dtypes)
print(heat1_ned.dtypes)
print(heat1_can.dtypes)
# Out:
# object
# GBR           float64
# Unnamed: 0    float64
# dtype: object
# ROU           float64
# Unnamed: 1    float64
# dtype: object
# NED           float64
# Unnamed: 2    float64
# dtype: object
# CAN           float64
# Unnamed: 3    float64
# dtype: object

# %%
# Heat 2

# Kopien erstellen und Renndaten zu float konvertieren

heat2_copy = heat2.copy()

race_data = heat2.iloc[3:43, 1:7].astype(float)

# Einteilen der Spalte pro Boot
dist = heat2_copy.iloc[3:43, 0]

heat2_ita = race_data.iloc[:, 0:2]

heat2_ger = race_data.iloc[:, 2:4]

heat2_usa = race_data.iloc[:, 4:6]


print(dist.dtypes)
print(heat2_ita.dtypes)
print(heat2_ger.dtypes)
print(heat2_usa.dtypes)
# Out:
# object
# ITA           float64
# Unnamed: 0    float64
# dtype: object
# GER           float64
# Unnamed: 1    float64
# dtype: object
# USA           float64
# Unnamed: 2    float64
# dtype: object

# %%
# Repecharge

# Kopien erstellen und Renndaten zu float konvertieren

rep_copy = rep.copy()

race_data = rep.iloc[3:43, 1:11].astype(float)

# Einteilen der Spalte pro Boot
dist = rep_copy.iloc[3:43, 0]

rep_rou = race_data.iloc[:, 0:2]

rep_can = race_data.iloc[:, 2:4]

rep_ned = race_data.iloc[:, 4:6]

rep_ger = race_data.iloc[:, 6:8]

rep_ita = race_data.iloc[:, 8:10]

print(dist.dtypes)
print(rep_rou.dtypes)
print(rep_can.dtypes)
print(rep_ned.dtypes)
print(rep_ger.dtypes)
print(rep_ita.dtypes)
# Out:
# object
# ROU           float64
# Unnamed: 0    float64
# dtype: object
# CAN           float64
# Unnamed: 1    float64
# dtype: object
# NED           float64
# Unnamed: 2    float64
# dtype: object
# GER           float64
# Unnamed: 3    float64
# dtype: object
# ITA           float64
# Unnamed: 4    float64
# dtype: object

# %%
# Final

# Kopien erstellen und Renndaten zu float konvertieren

final_copy = final.copy()

race_data = final.iloc[3:43, 1:13].astype(float)

# Einteilen der Spalte pro Boot
dist = final_copy.iloc[3:43, 0]

final_can = race_data.iloc[:, 0:2]

final_ger = race_data.iloc[:, 2:4]

final_usa = race_data.iloc[:, 4:6]

final_gbr = race_data.iloc[:, 6:8]

final_ned = race_data.iloc[:, 8:10]

final_ita = race_data.iloc[:, 10:12]

print(dist.dtypes)
print(final_can.dtypes)
print(final_ger.dtypes)
print(final_usa.dtypes)
print(final_gbr.dtypes)
print(final_ned.dtypes)
print(final_ita.dtypes)
# Out:
# object
# CAN           float64
# Unnamed: 0    float64
# dtype: object
# GER           float64
# Unnamed: 1    float64
# dtype: object
# USA           float64
# Unnamed: 2    float64
# dtype: object
# GBR           float64
# Unnamed: 3    float64
# dtype: object
# NED           float64
# Unnamed: 4    float64
# dtype: object
# ITA           float64
# Unnamed: 5    float64
# dtype: object

# %% [markdown]
# # Heat 1

# %% [markdown]
# ### GBR Heat1

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_gbr.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, marker='o', linestyle='-')
heat1_gbr_ms = sns.lineplot(x=x_data, y=y_data, marker='o', color='red')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1.columns[1]
rank = heat1.iloc[0, 1]
plot_title = f"Heat 1 {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_gbr.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
heat1_gbr_spm = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1_gbr.columns[0]
rank = heat1.iloc[0, 1]
plot_title = f"Heat 1 {nation} Rank {rank} Strokrate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('Spm')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### NED Heat 1

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_ned.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
heat1_ned_spm = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1.columns[5]
rank = heat1.iloc[0, 5]
plot_title = f"Heat 1 {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_ned.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
heat1_gbr_spm = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1_ned.columns[0]
rank = heat1.iloc[0, 5]
plot_title = f"Heat 1 {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### CAN Heat 1

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_can.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
heat1_ned_spm = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1_can.columns[0]
rank = heat1.iloc[0, 7]
plot_title = f"Heat 1 {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_can.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
heat1_gbr_spm = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1_can.columns[0]
rank = heat1.iloc[0, 5]
plot_title = f"Heat 1 {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### ROU Heat 1

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_rou.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
heat1_ned_spm = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1_rou.columns[0]
rank = heat1.iloc[0, 3]
plot_title = f"Heat 1 {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat1_rou.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
heat1_gbr_spm = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat1_rou.columns[0]
rank = heat1.iloc[0, 3]
plot_title = f"Heat 1 {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# # Heat 2

# %% [markdown]
# ### USA Heat 2

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat2_usa.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat2_usa.columns[0]
rank = heat2.iloc[0, 5]
plot_title = f"Heat 2 {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat2_usa.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat2_usa.columns[0]
rank = heat1.iloc[0, 5]
plot_title = f"Heat 2 {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Heat 2 GER

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat2_ger.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat2_ger.columns[0]
rank = heat2.iloc[0, 3]
plot_title = f"Heat 2 {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat2_ger.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat2_ger.columns[0]
rank = heat2.iloc[0, 3]
plot_title = f"Heat 2 {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Heat 2 ITA

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat2_ita.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat2_ita.columns[0]
rank = heat2.iloc[0, 1]
plot_title = f"Heat 2 {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = heat2_ita.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = heat2_ita.columns[0]
rank = heat1.iloc[0, 1]
plot_title = f"Heat 2 {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# # Repecharge

# %% [markdown]
# ### Rep ROU

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_rou.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_rou.columns[0]
rank = rep.iloc[0, 1]
plot_title = f"Rep {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_rou.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_rou.columns[0]
rank = rep.iloc[0, 1]
plot_title = f"Rep {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Rep CAN

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_can.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_can.columns[0]
rank = rep.iloc[0, 3]
plot_title = f"Rep {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_rou.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_rou.columns[0]
rank = rep.iloc[0, 3]
plot_title = f"Rep {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Rep NED

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_ned.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_ned.columns[0]
rank = rep.iloc[0, 5]
plot_title = f"Rep {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_ned.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_ned.columns[0]
rank = rep.iloc[0, 5]
plot_title = f"Rep {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Rep  GER

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_ger.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_ger.columns[0]
rank = rep.iloc[0, 7]
plot_title = f"Rep {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_ger.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_ger.columns[0]
rank = rep.iloc[0, 7]
plot_title = f"Rep {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Rep  ITA

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_ita.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_ita.columns[0]
rank = rep.iloc[0, 9]
plot_title = f"Rep {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = rep_rou.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = rep_rou.columns[0]
rank = rep.iloc[0, 9]
plot_title = f"Rep {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# # Final

# %% [markdown]
# ### Final CAN

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_can.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_can.columns[0]
rank = final.iloc[0, 1]
plot_title = f"Final {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_can.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_can.columns[0]
rank = final.iloc[0, 1]
plot_title = f"Final {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Final GER

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_ger.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_ger.columns[0]
rank = final.iloc[0, 3]
plot_title = f"Final {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_ger.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_ger.columns[0]
rank = final.iloc[0, 3]
plot_title = f"Final {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Final USA

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_usa.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_usa.columns[0]
rank = final.iloc[0, 5]
plot_title = f"Final {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_usa.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_usa.columns[0]
rank = final.iloc[0, 5]
plot_title = f"Final {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Final GBR

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_gbr.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_gbr.columns[0]
rank = final.iloc[0, 7]
plot_title = f"Final {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_gbr.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_gbr.columns[0]
rank = final.iloc[0, 7]
plot_title = f"Final {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Final NED

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_ned.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_ned.columns[0]
rank = rep.iloc[0, 9]
plot_title = f"Final {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_ned.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_ned.columns[0]
rank = final.iloc[0, 9]
plot_title = f"Final {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# ### Final ITA

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_ita.iloc[:, 0]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_ita.columns[0]
rank = final.iloc[0, 11]
plot_title = f"Final {nation} Rank {rank} Speed"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('m/s')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(y_data)*10), int(max(y_data)*10)+1)]
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %%
# Größe festlegen 30x15
plt.figure(figsize=(30, 15))

# Bestimmung der zu analysierenden Reihen und Spalten
x_data = dist[:40]
y_data = final_ita.iloc[:, 1]

# Linienplot erstellen
#plt.plot(x_data, y_data, color= 'red', marker='o', linestyle='-')
final_speed_ita = sns.lineplot(x=x_data, y=y_data, marker='o', color='blue', linestyle='-')

# Gitter anzeigen in leichtem Grau
plt.grid(color='lightgray')

# Achsentitel und Titel des Plots aus den Daten generieren
nation = final_ita.columns[0]
rank = final.iloc[0, 11]
plot_title = f"Final {nation} Rank {rank} Strokerate"

# Achsentitel und Titel des Plots setzen
plt.xlabel(nation)
plt.ylabel(rank)
plt.title(plot_title)

# Beschriftung der Achsen
plt.xlabel('Meter')
plt.ylabel('SPM')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = range(int(min(y_data)), int(max(y_data))+1)
plt.yticks(y_ticks)

# Plot anzeigen
plt.show()

# %% [markdown]
# # Race Comparison

# %% [markdown]
# ### ITA Strokerate

# %%
plt.figure(figsize=(30, 15))

# Lines Finale/Hoffnungslauf und Heat
sns.lineplot(x=dist[:40], y=final_ita.iloc[:, 1], color='blue', marker='o', label='Finale')
sns.lineplot(x=dist[:40], y=rep_ita.iloc[:, 1], color='red', marker='o', label='Repechage')
sns.lineplot(x=dist[:40], y=heat2_ita.iloc[:, 1], color='grey', marker='o', label='Heat')

#Achsen und Titelbeschriftung
plt.xlabel('Distance [m]')
plt.ylabel('Strokerate')
plt.title('SPM of Italy all races')

# Legende hinzufügen
plt.legend(bbox_to_anchor=(0.9, 1), loc='upper left')

# Gitter anzeigen
plt.grid(True)

plt.show()

# %% [markdown]
# ### GER Strokerate

# %%
plt.figure(figsize=(30, 15))

# Lines Finale/Hoffnungslauf und Heat
sns.lineplot(x=dist[:40], y=final_ger.iloc[:, 1], color='blue', marker='o', label='Finale')
sns.lineplot(x=dist[:40], y=rep_ger.iloc[:, 1], color='red', marker='o', label='Repechage')
sns.lineplot(x=dist[:40], y=heat2_ger.iloc[:, 1], color='purple', marker='o', label='Heat')

#Achsen und Titelbeschriftung
plt.xlabel('Distance [m]')
plt.ylabel('Strokerate [SPM]')
plt.title('Strokerate of Germany all races')

# Legende hinzufügen
plt.legend(bbox_to_anchor=(0.9, 1), loc='upper left')

# Gitter anzeigen
plt.grid(True)

plt.show()

# %% [markdown]
# ### GER Speed

# %%
plt.figure(figsize=(30, 15))

# Lines Finale/Hoffnungslauf und Heat
sns.lineplot(x=dist[:40], y=final_ger.iloc[:, 0], color='blue', marker='o', label='Finale')
sns.lineplot(x=dist[:40], y=rep_ger.iloc[:, 0], color='red', marker='o', label='Repechage')
sns.lineplot(x=dist[:40], y=heat2_ger.iloc[:, 0], color='purple', marker='o', label='Heat')

#Achsen und Titelbeschriftung
plt.xlabel('Distance [m]')
plt.ylabel('Speed [m/s]')
plt.title('Speed of Germany all races')

# Legende hinzufügen
plt.legend(bbox_to_anchor=(0.9, 1), loc='upper left')

# Y-Achsenticklabels manuell festlegen (0.1 Abstand)
y_ticks = [i/10 for i in range(int(min(heat2_ger.iloc[:, 0])*10), int(max(heat2_ger.iloc[:, 0])*10)+1)]
plt.yticks(y_ticks)

# Gitter anzeigen
plt.grid(True)

plt.show()
